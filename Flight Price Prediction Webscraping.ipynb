# %%
# Importing Libraries
import selenium
import pandas as pd
import time

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Pasting the installed msedge path
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# <ipython-input-126-a5c5aab88880>:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# # Yatra.com

# %%
#getting the url
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=26%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1483576700588"
driver.get(url)
time.sleep(2)

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df
# Out:
# <ipython-input-128-aea93edc1157>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-128-aea93edc1157>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-128-aea93edc1157>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-128-aea93edc1157>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=26%2F11%2F2021&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1127959296410&version=1.1&viewName=normal"
driver.get(url)
# Out:
# <ipython-input-129-7d928fc46536>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df1= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df1
# Out:
# <ipython-input-130-abe1f6b6360a>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-130-abe1f6b6360a>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-130-abe1f6b6360a>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-130-abe1f6b6360a>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=26%2F11%2F2021&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=46917662942&version=1.1&viewName=normal"
driver.get(url)
# Out:
# <ipython-input-134-65fd056f51d0>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df2= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df2
# Out:
# <ipython-input-135-01d4fa106698>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-135-01d4fa106698>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-135-01d4fa106698>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-135-01d4fa106698>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=26%2F11%2F2021&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=124520913907&version=1.1&viewName=normal"
driver.get(url)
# Out:
# <ipython-input-136-5fb6f67a54c1>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df3= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df3
# Out:
# <ipython-input-137-03449584183b>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-137-03449584183b>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-137-03449584183b>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-137-03449584183b>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %% [markdown]
# # makemytrip

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?itinerary=DEL-BOM-26/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
# Out:
# <ipython-input-138-4ebd3efd34f3>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df4= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df4
# Out:
# <ipython-input-139-f55f60ab5b67>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-139-f55f60ab5b67>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-139-f55f60ab5b67>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-139-f55f60ab5b67>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?itinerary=BOM-HYD-26/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
# Out:
# <ipython-input-140-a5a7f41b7225>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df5= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df5
# Out:
# <ipython-input-141-a15e321aba13>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-141-a15e321aba13>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-141-a15e321aba13>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-141-a15e321aba13>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?tripType=O&itinerary=HYD-MAA-26/11/2021&paxType=A-1_C-0_I-0&cabinClass=E&sTime=1637183288395&forwardFlowRequired=true&mpo=&intl=false"
driver.get(url)
# Out:
# <ipython-input-157-2cceadfe4de2>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df_1= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df_1
# Out:
# <ipython-input-158-e66d9a432915>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-158-e66d9a432915>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-158-e66d9a432915>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-158-e66d9a432915>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?itinerary=MAA-BLR-26/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
# Out:
# <ipython-input-143-f8e223eaba5e>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df6= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df6
# Out:
# <ipython-input-144-472352a9a297>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-144-472352a9a297>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-144-472352a9a297>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-144-472352a9a297>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?itinerary=MAA-IXC-26/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
# Out:
# <ipython-input-145-f94f3c5e7d2a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df7= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df7
# Out:
# <ipython-input-146-fcc50dd630d4>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-146-fcc50dd630d4>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-146-fcc50dd630d4>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-146-fcc50dd630d4>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.makemytrip.com/flight/search?tripType=O&itinerary=MAA-ATQ-26/11/2021&paxType=A-1_C-0_I-0&cabinClass=E&sTime=1637183567487&forwardFlowRequired=true&mpo=&intl=false"
driver.get(url)
# Out:
# <ipython-input-147-65d7e4c53725>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
    
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
    for i in time:
        depature.append(i.text)
except NoSuchElementException:
    depature.append('-')
    
#destination
depature_time=[]
arrival_time=[]
for i in range(0,len(depature)-1,2):
    depature_time.append(depature[i])
    arrival_time.append(depature[i+1])
    
    
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
    
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df8= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df8
# Out:
# <ipython-input-148-c30d0e5567fc>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="boldFont blackText airlineName"]')
# <ipython-input-148-c30d0e5567fc>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="darkText"]')
# <ipython-input-148-c30d0e5567fc>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]')
# <ipython-input-148-c30d0e5567fc>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=HYD&destinationCountry=IN&flight_depart_date=26%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=11883954694"
driver.get(url)
# Out:
# <ipython-input-149-11ae38384d93>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df9= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df9
# Out:
# <ipython-input-150-953812b9644d>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-150-953812b9644d>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-150-953812b9644d>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-150-953812b9644d>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=VGA&destinationCountry=IN&flexi=0&flight_depart_date=26%2F11%2F2021&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1070688275609&version=1.1&viewName=normal"
driver.get(url)
# Out:
# <ipython-input-151-0f55c4c5f4a3>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df10= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df10
# Out:
# <ipython-input-153-83f214b27cc0>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-153-83f214b27cc0>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-153-83f214b27cc0>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-153-83f214b27cc0>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %%
#getting the url
driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=IXC&destinationCountry=IN&flexi=0&flight_depart_date=26%2F11%2F2021&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=580189535390&version=1.1&viewName=normal"
driver.get(url)
# Out:
# <ipython-input-154-36443d85bcaa>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Airline details
airline_name=[]  
try:
    name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in name:
        airline_name.append(i.text)
except NoSuchElementException:
    airline_name.append('-')
#place
source=[]
try:
    Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
    for i in Source:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#Source  
Source=[]
for i in range(0,len(source)-1,2):
    Source.append(source[i])
#destination
destination=[]
for i in range(0,len(source)-1,2):
    destination.append(source[i+1])
# total stops
stops=[]
try:
    stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
    for i in stop:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('-')
#departure time 
depature_time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in time:
        depature_time.append(i.text)
except NoSuchElementException:
    depature_time.append('-')
#Arrival time
arrival_time=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in time:
        arrival_time.append(i.text)
except NoSuchElementException:
    arrival_time.append('-')
#duration
duration=[]
try:
    time=driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in time:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')
#fare
price=[]
try:
    fare=driver.find_elements_by_xpath('//div[@class="pr i-b mr-2"]')
    for i in fare:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')
#Making dataframe
# creating a pandas dataframe
df10= pd.DataFrame({'airline_name':airline_name,'date_of_journey':'26/11/2021','Source':Source,'Destination':destination,'depature_time':depature_time,'arrival_time':arrival_time,'duration':duration,'total_stops':stops,'Price':price})
  # show the dataframe
df10
# Out:
# <ipython-input-155-83f214b27cc0>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
# <ipython-input-155-83f214b27cc0>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Source=driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
# <ipython-input-155-83f214b27cc0>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stop=driver.find_elements_by_xpath('//span[@class="dotted-borderbtm" or @class="cursor-default"]')
# <ipython-input-155-83f214b27cc0>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   time=driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# ...

# %% [markdown]
# # concatinating the dataframes

# %%
data=pd.concat([df,df1,df2,df3,df4,df5,df_1,df6,df7,df8,df9,df10],ignore_index=True)

# %%
data
# Out:
#     airline_name date_of_journey     Source Destination depature_time  \
# 0       Go First      26/11/2021  New Delhi      Mumbai         11:50
# 1       Go First      26/11/2021  New Delhi      Mumbai         09:00
# 2       Go First      26/11/2021  New Delhi      Mumbai         09:10
# 3       Go First      26/11/2021  New Delhi      Mumbai         10:30
# 4       Go First      26/11/2021  New Delhi      Mumbai         05:25
# ..           ...             ...        ...         ...           ...
# 283      Vistara      26/11/2021  New Delhi  Chandigarh         15:30
# 284      Vistara      26/11/2021  New Delhi  Chandigarh         14:20
# 285      Vistara      26/11/2021  New Delhi  Chandigarh         12:50
# 286      Vistara      26/11/2021  New Delhi  Chandigarh         11:40
# 287      Vistara      26/11/2021  New Delhi  Chandigarh         10:20
#
#        arrival_time duration total_stops           Price
# 0             18:10   6h 20m      1 Stop  4 left at4,941
# ...

# %% [markdown]
# # Saving into excel file

# %%
# writing to Excel
datatoexcel = pd.ExcelWriter('flight_price_prediction_1.xlsx')
  
# write DataFrame to excel
data.to_excel(datatoexcel)
  
# save to excel
datatoexcel.save()
